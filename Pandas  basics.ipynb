# %% [markdown]
# # PANDAS

# %%
import pandas as pd

# %%
#Calling the data_set to pandas
data = pd.read_csv('./Titanic.csv')

# %%
#displaying the first five rows of the data
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Embarked WikiId  \
# 0      0         A/5 21171   7.2500  ...        S  691.0
# 1      0          PC 17599  71.2833  ...        C   90.0
# 2      0  STON/O2. 3101282   7.9250  ...        S  865.0
# 3      0            113803  53.1000  ...        S  127.0
# ...

# %%
#displaying the first ten rows of the data 
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
# 8            9       1.0       3
# 9           10       1.0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.tail(10)
# Out:
#       PassengerId  Survived  Pclass  \
# 1299         1300       NaN       3
# 1300         1301       NaN       3
# 1301         1302       NaN       3
# 1302         1303       NaN       1
# 1303         1304       NaN       3
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1299                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 1300                        Peacock, Miss. Treasteall  female   3.0      1
# 1301                           Naughton, Miss. Hannah  female   NaN      0
# 1302  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 1303                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 1304                               Spector, Mr. Woolf    male   NaN      0
# ...

# %%
data.sample(20)
# Out:
#       PassengerId  Survived  Pclass  \
# 1274         1275       NaN       3
# 997           998       NaN       3
# 1147         1148       NaN       3
# 1198         1199       NaN       3
# 801           802       1.0       2
# 494           495       0.0       3
# 365           366       0.0       3
# 821           822       1.0       3
# 1074         1075       NaN       3
# 683           684       0.0       3
# 145           146       0.0       2
# 941           942       NaN       1
# 328           329       1.0       3
# 222           223       0.0       3
# 444           445       1.0       3
# 468           469       0.0       3
# 977           978       NaN       3
# 768           769       0.0       3
# 957           958       NaN       3
# 142           143       1.0       3
#
#                                                    Name     Sex    Age  SibSp  \
# 1274                McNamee, Mrs. Neal (Eileen O'Leary)  female  19.00      1
# ...

# %%
#It will disply the number of rows amd columns in the data_set 
data.shape
# Out:
# (1309, 21)

# %%
#It will disply all the column values
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')

# %%
#It will disply the details of the data_set as non null values and it's type
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  WikiId       1304 non-null   float64
#  13  Name_wiki    1304 non-null   object
#  14  Age_wiki     1302 non-null   float64
#  15  Hometown     1304 non-null   object
#  16  Boarded      1304 non-null   object
#  17  Destination  1304 non-null   object
# ...

# %%
#It will show the mean,count,std,min,percentiles,max
data.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare       WikiId     Age_wiki        Class
# count  1309.000000  1308.000000  1304.000000  1302.000000  1304.000000
# mean      0.385027    33.295479   658.534509    29.415829     2.291411
# std       0.865560    51.758668   380.377373    13.758954     0.840852
# ...

# %%
#It will disply transpose of the entry "data.describe()"
data.describe().T
# Out:
#               count        mean         std   min       25%       50%  \
# PassengerId  1309.0  655.000000  378.020061  1.00  328.0000  655.0000
# Survived      891.0    0.383838    0.486592  0.00    0.0000    0.0000
# Pclass       1309.0    2.294882    0.837836  1.00    2.0000    3.0000
# Age          1046.0   29.881138   14.413493  0.17   21.0000   28.0000
# SibSp        1309.0    0.498854    1.041658  0.00    0.0000    0.0000
# Parch        1309.0    0.385027    0.865560  0.00    0.0000    0.0000
# Fare         1308.0   33.295479   51.758668  0.00    7.8958   14.4542
# WikiId       1304.0  658.534509  380.377373  1.00  326.7500  661.5000
# Age_wiki     1302.0   29.415829   13.758954  0.17   21.0000   28.0000
# Class        1304.0    2.291411    0.840852  1.00    1.7500    3.0000
#
#                  75%        max
# PassengerId  982.000  1309.0000
# Survived       1.000     1.0000
# Pclass         3.000     3.0000
# Age           39.000    80.0000
# ...

# %%
#It will disply the null values of the data_set as bool
data.isnull()
# Out:
#       PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  \
# 0           False     False   False  False  False  False  False  False
# 1           False     False   False  False  False  False  False  False
# 2           False     False   False  False  False  False  False  False
# 3           False     False   False  False  False  False  False  False
# 4           False     False   False  False  False  False  False  False
# ...           ...       ...     ...    ...    ...    ...    ...    ...
# 1304        False      True   False  False  False   True  False  False
# 1305        False      True   False  False  False  False  False  False
# 1306        False      True   False  False  False  False  False  False
# 1307        False      True   False  False  False   True  False  False
# 1308        False      True   False  False  False   True  False  False
#
#       Ticket   Fare  ...  Embarked  WikiId  Name_wiki  Age_wiki  Hometown  \
# ...

# %%
#It will disply the null values of the data_set as sum
data.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# WikiId            5
# Name_wiki         5
# Age_wiki          7
# Hometown          5
# Boarded           5
# Destination       5
# Lifeboat        807
# Body           1179
# Class             5
# dtype: int64

# %% [markdown]
# # Null percentage

# %%
#It will disply the mean null value
data.isnull().mean()
# Out:
# PassengerId    0.000000
# Survived       0.319328
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.200917
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000764
# Cabin          0.774637
# Embarked       0.001528
# WikiId         0.003820
# Name_wiki      0.003820
# Age_wiki       0.005348
# Hometown       0.003820
# Boarded        0.003820
# Destination    0.003820
# Lifeboat       0.616501
# Body           0.900688
# Class          0.003820
# dtype: float64

# %%
#mean*100 = percentage , eg survived/Total persons = mean(values~(0-1)) 
data.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived       31.932773
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.091673
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.076394
# Cabin          77.463713
# Embarked        0.152788
# WikiId          0.381971
# Name_wiki       0.381971
# Age_wiki        0.534759
# Hometown        0.381971
# Boarded         0.381971
# Destination     0.381971
# Lifeboat       61.650115
# Body           90.068755
# Class           0.381971
# dtype: float64

# %% [markdown]
# # Dropping the columns

# %%
#It will drop the values of the 4 given columns from the data_set
data.drop(columns=['Body','Lifeboat','Cabin','PassengerId'])
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
data
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
#Here by using "inplace" we are assigning the values to the data_set
data.drop(columns=['Body','Lifeboat','Cabin','PassengerId'], inplace=True)

# %%
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %% [markdown]
# # Finding unique values

# %%
#It will disply the unique values of Pclass
#Here the repeating values of Pclass are [1,2,3]
data.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
data.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# # Total items in a column

# %%
#For finding the sum of items within a specific column
data.Sex.value_counts()
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %% [markdown]
# # Filling NaN values

# %%
data.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data.Embarked.value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
# Filling the value "S" to all the null values
data.Embarked.fillna("S", inplace=True)

# %%
#checking the whole null values within every columns
#we are also checking the ull values of the column "Embarked"
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Embarked         0
# WikiId           5
# Name_wiki        5
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %% [markdown]
# # MEAN

# %%
# finding the mean value of "Fare"
fare_mean = data.Fare.mean()
fare_mean
# Out:
# 33.2954792813456

# %%
#filling the mean value to the null values of th column "Fare"
data.Fare.fillna(fare_mean, inplace= True
            )

# %%
#finding the sum of the null values within the whole columns in the dataset
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# WikiId           5
# Name_wiki        5
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
#another example
#finding the most occuring value
data.Age.mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
data.Age.fillna(24.0,inplace=True)

# %% [markdown]
# # GROUP BY

# %%
# To find the class of the survived passengers
Pclass_survived = data.groupby(['Pclass'])["Survived"].sum()

# %%
Pclass_survived
# Out:
# Pclass
# 1    136.0
# 2     87.0
# 3    119.0
# Name: Survived, dtype: float64

# %% [markdown]
# # QUERY

# %% [markdown]
# Boarded_southampton

# %%
#It help us to find a specific query from columns in a dataset
Boarded_southampton = data.query("Boarded == 'Southampton'")

# %%
Boarded_southampton
# Out:
#       Survived  Pclass                                             Name  \
# 0          0.0       3                          Braund, Mr. Owen Harris
# 2          1.0       3                           Heikkinen, Miss. Laina
# 3          1.0       1     Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                         Allen, Mr. William Henry
# 6          0.0       1                          McCarthy, Mr. Timothy J
# ...        ...     ...                                              ...
# 1302       NaN       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1303       NaN       3                   Henriksson, Miss. Jenny Lovisa
# 1304       NaN       3                               Spector, Mr. Woolf
# 1306       NaN       3                     Saether, Mr. Simon Sivertsen
# 1307       NaN       3                              Ware, Mr. Frederick
#
#          Sex   Age  SibSp  Parch              Ticket     Fare Embarked  \
# ...

# %%
# For finding persons borded from southampton who is 28 years old
Boarded_southampton_age28 = data.query("Boarded=='Southampton' & Age==28.0")

# %%
Boarded_southampton_age28
# Out:
#       Survived  Pclass                                               Name  \
# 23         1.0       1                       Sloper, Mr. William Thompson
# 83         0.0       1                            Carrau, Mr. Francisco M
# 100        0.0       3                            Petranec, Miss. Matilda
# 105        0.0       3                              Mionoff, Mr. Stoytcho
# 169        0.0       3                                      Ling, Mr. Lee
# 200        0.0       3                     Vande Walle, Mr. Nestor Cyriel
# 281        0.0       3                   Olsson, Mr. Nils Johan Goransson
# 313        0.0       3                             Hendekovic, Mr. Ignjac
# 342        0.0       2                         Collander, Mr. Erik Gustaf
# 355        0.0       3                        Vanden Steen, Mr. Leo Peter
# 392        0.0       3                       Gustafsson, Mr. Johan Birger
# 399        1.0       2                   Trout, Mrs. William H (Jessie L)
# ...
